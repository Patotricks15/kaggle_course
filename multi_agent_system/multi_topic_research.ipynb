# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)
# Out:
# ✅ ADK components imported successfully.

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/home/poliv/kaggle_course/venv/lib/python3.12/site-packages/google/adk/agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > Here's a concise report on the latest AI/ML trends:
#
# **Key AI/ML Developments:**
#
# 1.  **Generative AI Expansion:** Advanced models can now create complex content like video and music, moving beyond text. Companies like Google (Imagen, Muse) and OpenAI are leading this, with tools like Runway ML enabling sophisticated video production.
# 2.  **Agentic AI:** Autonomous AI systems are evolving to handle entire tasks with minimal human input, streamlining complex business workflows. The market for autonomous AI is projected for significant growth.
# 3.  **Domain-Specific and Smaller Models (SLMs):** Specialized AI models are increasingly outperforming general ones, offering tailored solutions and efficiency. This shift from large language models (LLMs) to smaller, more optimized models is a key trend.
#
# **Main Companies Involved:**
#
# *   **Tech Giants:** Google, Microsoft, Amazon, NVIDIA, and IBM are major players investing heavily in AI research, development, and cloud platforms.
# *   **AI Startups & Specialists:** Companies like OpenAI, Anthropic, Stability AI, and Synthesia are at the forefront of generative AI and specialized AI applications.
#
# **Potential Impact:**
#
# These trends promise increased automation, enhanced productivity, and novel content creation capabilities across industries. However, they also raise important considerations around ethical AI, data governance, and workforce adaptation.
# FinanceResearcher > **Tech:** A critical vulnerability in React Server Components (CVE-2025–55182) is a major concern, impacting millions of web applications and requiring immediate patching. OpenAI is funding grassroots AI initiatives with $40.5 million for 208 nonprofits.
#
# **Health:** An AI platform for cancer diagnosis, "C the Signs," has shown an 808% ROI for the NHS, leading to earlier diagnoses and significant cost savings. The European Society for Medical Oncology has released global guidance on validating AI-based biomarkers in cancer care.
#
# **Finance:** Investors are betting on a Federal Reserve interest-rate cut, with an 85% probability priced in for a 25-basis-point reduction. This sentiment is influenced by weaker-than-expected labor market data. The UK's Financial Conduct Authority will not immediately investigate pre-budget briefings, but reserves the right to examine potential market manipulation.
#
# ***
#
# ### Fintech Trends Briefing
#
# **1. Embedded Finance:**
# *   **Market Implication:** Financial services are increasingly integrated into non-financial platforms (e.g., e-commerce checkout, ride-sharing apps), offering seamless user experiences and new revenue streams for both financial institutions and partners.
# *   **Future Outlook:** Expect broader adoption across more industries, with a focus on personalization and data-driven insights to tailor financial products at the point of need.
#
# **2. AI and Machine Learning in Financial Services:**
# *   **Market Implication:** AI/ML is revolutionizing areas like fraud detection, credit scoring, personalized financial advice (robo-advisors), and algorithmic trading, leading to greater efficiency, accuracy, and customer satisfaction.
# *   **Future Outlook:** Continued advancement in AI capabilities will drive hyper-personalization, predictive analytics for risk management, and more sophisticated automated financial advisory services.
#
# **3. Decentralized Finance (DeFi):**
# *   **Market Implication:** DeFi platforms offer alternative financial services (lending, borrowing, trading) built on blockchain technology, promoting transparency, accessibility, and potentially lower costs by removing intermediaries.
# *   **Future Outlook:** While facing regulatory hurdles, DeFi is poised for growth as it matures, offering innovative financial instruments and challenging traditional banking models, with increasing interoperability between DeFi and traditional finance.
# HealthResearcher > **Health Breakthroughs:** mRNA vaccine technology, initially proven with COVID-19, is now being explored for other diseases, with an estimated timeline for broader application within the next decade. AI-driven sepsis detection systems are demonstrating significant reductions in mortality rates, with ongoing development to predict other conditions like kidney and heart failure, aiming for wider hospital adoption in the near future. The development of new diagnostic tests and treatments, including more effective and accessible vaccines and therapies, continues to improve global health outcomes.
#
# **Tech Breakthroughs:** 6G network development is progressing, with potential commercial deployments around 2030, promising speeds 100 times faster than 5G to enable advanced automation and immersive experiences. Agentic AI, or "virtual coworkers," are moving from pilot projects to practical applications, enhancing decision-making and automating complex workflows, with significant enterprise adoption anticipated by 2025. Quantum computing advancements are ongoing, with initial utility-scale value expected in the coming years, potentially revolutionizing data processing and problem-solving.
#
# **Finance Breakthroughs:** AI is increasingly informing core financial decisions like credit and insurance underwriting, with potential to shift capital allocation. The development of advanced AI, including generative and agentic AI, is set to personalize financial services and enhance customer experiences. Blockchain technology continues to find new use cases in finance, with ongoing innovation in decentralized finance (DeFi).
# AggregatorAgent > ## Executive Briefing: Tech, Health, and Finance - April 11, 2024
#
# **AI Dominates Innovation Across Sectors:** Artificial Intelligence is the central theme across technology, health, and finance, driving transformative advancements. In **technology**, Generative AI is expanding into video and music creation, while Agentic AI promises autonomous task completion. The rise of specialized, smaller AI models offers tailored efficiency. Simultaneously, **health** is seeing significant AI impact, with platforms like "C the Signs" demonstrating exceptional ROI for cancer diagnosis and AI aiding in sepsis detection to reduce mortality. Beyond AI, mRNA vaccine technology is being explored for broader applications.
#
# **Finance Leverages AI and Emerging Tech:** The **finance** sector is deeply integrating AI for credit scoring, fraud detection, and personalized advice. Agentic AI is set to enhance decision-making and customer experiences, with significant enterprise adoption expected by 2025. Decentralized Finance (DeFi) continues to evolve, offering alternative financial services. On the tech front, a critical vulnerability in React Server Components necessitates immediate attention, while advancements in 6G and quantum computing signal future capabilities. Market sentiment in finance is currently driven by anticipated Federal Reserve interest rate adjustments, influenced by labor market data.
#
# **Key Takeaways:**
#
# *   **AI is a Universal Enabler:** From content creation to disease diagnosis and financial services, AI is the primary driver of innovation.
# *   **Efficiency and Personalization are Paramount:** Both specialized AI models and advancements in financial services focus on tailored solutions and improved user experiences.
# *   **Emerging Technologies Signal Future Shifts:** While AI is current, developments in mRNA, 6G, and quantum computing point towards significant future disruptions.
