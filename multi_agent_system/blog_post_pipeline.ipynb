# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/home/poliv/kaggle_course/venv/lib/python3.12/site-packages/google/adk/agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > Okay, I am OutlineAgent. Here is a blog outline about the benefits of multi-agent systems for software developers.
#
# ### Blog Outline:
#
# **Headline:** Unleash the Power of Collaboration: How Multi-Agent Systems Will Revolutionize Your Software Development
#
# **Introduction Hook:** Imagine a team of intelligent, independent "robots" working tirelessly behind the scenes of your software projects, handling complex tasks, optimizing processes, and even anticipating your needs. This isn't science fiction anymore. Multi-agent systems (MAS) are emerging as a transformative technology, offering software developers unprecedented opportunities to build more robust, efficient, and adaptable applications.
#
# **Main Sections:**
#
# **1. Enhanced Problem Solving and Complexity Management**
#     *   **Decomposition of Complex Tasks:** Break down large, intricate problems into smaller, manageable sub-problems that individual agents can tackle independently. This makes the overall development process less daunting and easier to oversee.
#     *   **Parallel Processing and Speed:** Multiple agents can operate concurrently, significantly accelerating development cycles, testing, and deployment by distributing the workload across specialized units.
#     *   **Adaptive and Resilient Systems:** MAS can inherently handle unexpected events or failures. If one agent encounters an issue, others can adapt and compensate, leading to more resilient and fault-tolerant software.
#
# **2. Improved Modularity, Scalability, and Reusability**
#     *   **Independent Agent Development:** Each agent can be developed, tested, and maintained in isolation, reducing interdependencies and potential for cascading errors that plague monolithic systems.
#     *   **Dynamic Scalability:** Easily add or remove agents based on demand or project needs, allowing for flexible scaling of system capabilities without major architectural overhauls.
#     *   **Reusable Agent Components:** Design agents that perform specific functions and can be reused across different projects or within different parts of the same application, saving development time and effort.
#
# **3. Intelligent Automation and Optimization**
#     *   **Automated Decision-Making:** Agents can be programmed to make autonomous decisions based on predefined rules, learned behaviors, or interactions with other agents, reducing manual intervention in complex scenarios.
#     *   **Resource Optimization:** Agents can actively monitor and manage system resources, optimizing their allocation and usage to improve performance and reduce operational costs.
#     *   **Proactive Issue Detection and Resolution:** Agents can be designed to monitor system health, identify potential issues before they impact users, and even initiate self-healing or corrective actions.
#
# **Concluding Thought:** Multi-agent systems represent a paradigm shift in how we conceptualize and build software. By embracing this collaborative, decentralized approach, software developers can unlock new levels of efficiency, resilience, and intelligence, paving the way for the next generation of sophisticated applications. It's time to start exploring how your next project can benefit from the power of multi-agent collaboration.
# WriterAgent > ## Unleash the Power of Collaboration: How Multi-Agent Systems Will Revolutionize Your Software Development
#
# Imagine a team of intelligent, independent "robots" working tirelessly behind the scenes of your software projects, handling complex tasks, optimizing processes, and even anticipating your needs. This isn't science fiction anymore. Multi-agent systems (MAS) are emerging as a transformative technology, offering software developers unprecedented opportunities to build more robust, efficient, and adaptable applications.
#
# One of the most significant benefits of MAS lies in **enhanced problem-solving and complexity management**. Large, intricate problems can be elegantly decomposed into smaller, manageable sub-problems, each tackled by specialized agents. This parallel processing capability dramatically accelerates development cycles and testing. Furthermore, MAS inherently builds resilience; if one agent encounters an issue, others can adapt and compensate, leading to fault-tolerant systems.
#
# MAS also champions **improved modularity, scalability, and reusability**. Agents can be developed, tested, and maintained in isolation, drastically reducing the dreaded interdependencies that plague monolithic systems. Need to scale up? Simply add more agents. Looking for efficiency? Design agents for specific functions and reuse them across projects. This independent development and dynamic scalability save immense development time and effort.
#
# Finally, MAS unlocks **intelligent automation and optimization**. Agents can be programmed for autonomous decision-making, optimizing resource allocation and usage to boost performance and cut costs. They can even proactively monitor system health, detect potential issues, and initiate self-healing actions before they impact users.
#
# Multi-agent systems represent a paradigm shift, enabling software developers to unlock new levels of efficiency, resilience, and intelligence. It's time to explore how your next project can benefit from this powerful collaborative approach.
# EditorAgent > ## Unleash the Power of Collaboration: How Multi-Agent Systems Will Revolutionize Your Software Development
#
# Imagine a team of intelligent, independent "robots" working tirelessly behind the scenes of your software projects, handling complex tasks, optimizing processes, and even anticipating your needs. This isn't science fiction anymore. Multi-agent systems (MAS) are emerging as a transformative technology, offering software developers unprecedented opportunities to build more robust, efficient, and adaptable applications.
#
# One of the most significant benefits of MAS lies in **enhanced problem-solving and complexity management**. Large, intricate problems can be elegantly decomposed into smaller, manageable sub-problems, each tackled by specialized agents. This parallel processing capability dramatically accelerates development cycles and testing. Furthermore, MAS inherently builds resilience; if one agent encounters an issue, others can adapt and compensate, leading to fault-tolerant systems.
#
# MAS also champions **improved modularity, scalability, and reusability**. Agents can be developed, tested, and maintained in isolation, drastically reducing the dreaded interdependencies that plague monolithic systems. Need to scale up? Simply add more agents. Looking for efficiency? Design agents for specific functions and reuse them across projects. This independent development and dynamic scalability save immense development time and effort.
#
# Finally, MAS unlocks **intelligent automation and optimization**. Agents can be programmed for autonomous decision-making, optimizing resource allocation and usage to boost performance and cut costs. They can even proactively monitor system health, detect potential issues, and initiate self-healing actions before they impact users.
#
# Multi-agent systems represent a paradigm shift, enabling software developers to unlock new levels of efficiency, resilience, and intelligence. It's time to explore how your next project can benefit from this powerful collaborative approach.
