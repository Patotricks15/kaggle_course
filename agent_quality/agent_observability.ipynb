# %%
from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.tools.agent_tool import AgentTool
from google.adk.tools.google_search_tool import google_search

from google.genai import types
from typing import List

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %%
def count_papers(papers: List[str]):
    """
    This function counts the number of papers in a list of strings.
    Args:
      papers: A list of strings, where each string is a research paper.
    Returns:
      The number of papers in the list.
    """
    return len(papers)

# %%
# Google search agent
google_search_agent = LlmAgent(
    name="google_search_agent",
    model=Gemini(model="gemini-2.5-flash", retry_options=retry_config),
    description="Searches for information using Google search",
    instruction="Use the google_search tool to find information on the given topic. Return the raw search results.",
    tools=[google_search],
)

# Root agent
research_agent_with_plugin = LlmAgent(
    name="research_paper_finder_agent",
    model=Gemini(model="gemini-2.5-flash", retry_options=retry_config),
    instruction="""Your task is to find research papers and count them. 
   
   You must follow these steps:
   1) Find research papers on the user provided topic using the 'google_search_agent'. 
   2) Then, pass the papers to 'count_papers' tool to count the number of papers returned.
   3) Return both the list of research papers and the total number of papers.
   """,
    tools=[AgentTool(agent=google_search_agent), count_papers],
)

print("✅ Agent created")
# Out:
# ✅ Agent created

# %%
from google.adk.runners import InMemoryRunner
from google.adk.plugins.logging_plugin import (
    LoggingPlugin,
)  # <---- 1. Import the Plugin
from google.genai import types
import asyncio

runner = InMemoryRunner(
    agent=research_agent_with_plugin,
    plugins=[
        LoggingPlugin()
    ],  # <---- 2. Add the plugin. Handles standard Observability logging across ALL agents
)

print("✅ Runner configured")
# Out:
# ✅ Runner configured

# %%
print("🚀 Running agent with LoggingPlugin...")
print("📊 Watch the comprehensive logging output below:\n")

response = await runner.run_debug("Find recent papers on geology")
# Out:
# 🚀 Running agent with LoggingPlugin...
# 📊 Watch the comprehensive logging output below:
#
#
#  ### Created new session: debug_session_id
#
# User > Find recent papers on geology
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-38c8caf4-818e-47da-925b-e39ed7f29f20
# [logging_plugin]    Session ID: debug_session_id
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: research_paper_finder_agent
# [logging_plugin]    User Content: text: 'Find recent papers on geology'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-38c8caf4-818e-47da-925b-e39ed7f29f20
# [logging_plugin]    Starting Agent: research_paper_finder_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: research_paper_finder_agent
# [logging_plugin]    Invocation ID: e-38c8caf4-818e-47da-925b-e39ed7f29f20
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    System Instruction: 'Your task is to find research papers and count them.
#
#    You must follow these steps:
#    1) Find research papers on the user provided topic using the 'google_search_agent'.
#    2) Then, pass the pape...'
# [logging_plugin]    Available Tools: ['google_search_agent', 'count_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Content: function_call: google_search_agent
# [logging_plugin]    Token Usage - Input: 239, Output: 20
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f87b119e-bdcb-4997-a5cb-e4c666bce02b
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_call: google_search_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['google_search_agent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: google_search_agent
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-c43703df-e233-4f1d-9f11-65b40116580b
# [logging_plugin]    Arguments: {'request': 'recent papers on geology'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-634c9196-ecf2-4254-8391-59851bc5afdc
# [logging_plugin]    Session ID: 3a1e5175-aaa6-4621-9508-5b429651150e
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: google_search_agent
# [logging_plugin]    User Content: text: 'recent papers on geology'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-634c9196-ecf2-4254-8391-59851bc5afdc
# [logging_plugin]    Starting Agent: google_search_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: google_search_agent
# [logging_plugin]    Invocation ID: e-634c9196-ecf2-4254-8391-59851bc5afdc
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: google_search_agent
# [logging_plugin]    System Instruction: 'Use the google_search tool to find information on the given topic. Return the raw search results.
#
# You are an agent. Your internal name is "google_search_agent". The description about you is "Searches...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: google_search_agent
# [logging_plugin]    Content: text: 'Here's a compilation of recent papers and discoveries in the field of geology, highlighting key findings and prominent publications in 2024:
#
# **Key Geological Discoveries and Research Highlights in 20...'
# [logging_plugin]    Token Usage - Input: 57, Output: 1225
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 084488ca-d3d6-4fb0-9316-bfd53ca23e17
# [logging_plugin]    Author: google_search_agent
# [logging_plugin]    Content: text: 'Here's a compilation of recent papers and discoveries in the field of geology, highlighting key findings and prominent publications in 2024:
#
# **Key Geological Discoveries and Research Highlights in 20...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: google_search_agent
# [logging_plugin]    Invocation ID: e-634c9196-ecf2-4254-8391-59851bc5afdc
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-634c9196-ecf2-4254-8391-59851bc5afdc
# [logging_plugin]    Final Agent: google_search_agent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: google_search_agent
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-c43703df-e233-4f1d-9f11-65b40116580b
# [logging_plugin]    Result: Here's a compilation of recent papers and discoveries in the field of geology, highlighting key findings and prominent publications in 2024:
#
# **Key Geological Discoveries and Research Highlights in 2024:**
#
# *   **Dark Oxygen and Ocean Ecosystems:** Researchers have identified "dark oxygen," a myster...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0b91c2ce-4895-4a88-9b26-6a5a68f9947e
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_response: google_search_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['google_search_agent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    System Instruction: 'Your task is to find research papers and count them.
#
#    You must follow these steps:
#    1) Find research papers on the user provided topic using the 'google_search_agent'.
#    2) Then, pass the pape...'
# [logging_plugin]    Available Tools: ['google_search_agent', 'count_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Content: function_call: count_papers
# [logging_plugin]    Token Usage - Input: 1485, Output: 112
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 68b74f02-17c4-4765-9aa2-331318606b3d
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_call: count_papers
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['count_papers']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: count_papers
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-9e868824-8650-4975-a948-344b773115e4
# [logging_plugin]    Arguments: {'papers': ['Dark Oxygen and Ocean Ecosystems', 'Unidentified Seismic Objects (USOs)', 'Deep Subterranean Life Forms', 'Ancient Magnetic Field Insights', 'New Mineral Formation Pathways', 'Accelerated Glacial Melting Rates', 'Landslides and Seismic Waves', 'Earthquakes and Gold Formation', 'Early Pl...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: count_papers
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-9e868824-8650-4975-a948-344b773115e4
# [logging_plugin]    Result: 13
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: a4448607-dbc4-4136-bf16-532bbdbe7984
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_response: count_papers
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['count_papers']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    System Instruction: 'Your task is to find research papers and count them.
#
#    You must follow these steps:
#    1) Find research papers on the user provided topic using the 'google_search_agent'.
#    2) Then, pass the pape...'
# [logging_plugin]    Available Tools: ['google_search_agent', 'count_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Content: text: 'Here are the recent papers on geology:
#
# *   **Dark Oxygen and Ocean Ecosystems:** Researchers have identified \"dark oxygen,\" a mysterious form of oxygen originating from metallic deposits on the oce...'
# [logging_plugin]    Token Usage - Input: 1613, Output: 672
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 219a19c9-0cb9-411d-b66e-511660d5d4d7
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: text: 'Here are the recent papers on geology:
#
# *   **Dark Oxygen and Ocean Ecosystems:** Researchers have identified \"dark oxygen,\" a mysterious form of oxygen originating from metallic deposits on the oce...'
# [logging_plugin]    Final Response: True
# research_paper_finder_agent > Here are the recent papers on geology:
#
# *   **Dark Oxygen and Ocean Ecosystems:** Researchers have identified \"dark oxygen,\" a mysterious form of oxygen originating from metallic deposits on the ocean floor, which challenges existing models of atmospheric chemistry and could significantly alter our understanding of ocean ecosystems and life in deep ocean environments.
# *   **Unidentified Seismic Objects (USOs):** Seismologists have detected anomalies within Earth\'s subsurface, termed USOs, which exhibit unique seismic signatures. Their origins are currently unknown, prompting further investigation into Earth\'s internal processes and potentially undiscovered subterranean structures.
# *   **Deep Subterranean Life Forms:** Advancements in deep-earth exploration have led to the discovery of microbial life existing several kilometers beneath the Earth\'s surface. These extremophiles thrive in high-pressure, low-nutrient conditions, expanding the known limits of life and informing the search for extraterrestrial life.
# *   **Ancient Magnetic Field Insights:** Studies of ancient rock formations, particularly those found in Greenland (approximately 3.7 billion years old), have provided new data on Earth\'s magnetic field history, suggesting more frequent and rapid reversals than previously thought. This extends the known age of Earth\'s magnetic field by hundreds of millions of years, potentially influencing the emergence of life.
# *   **New Mineral Formation Pathways:** Geologists have identified new mechanisms for mineral formation under extreme conditions within Earth\'s mantle, leading to minerals with unique properties and offering insights into geochemical cycles.
# *   **Accelerated Glacial Melting Rates:** Satellite observations in 2024 have recorded unprecedented melting rates in glaciers previously considered stable, contributing to rising sea levels and impacting freshwater resources.
# *   **Landslides and Seismic Waves:** A massive landslide in Greenland\'s Dickson Fjord was identified as the cause of a persistent, unexplained seismic humming noise detected in 2023, triggering a tsunami that created prolonged wave activity.
# *   **Earthquakes and Gold Formation:** Research in 2024 suggests that earthquakes might play a role in the creation of gold nuggets.
# *   **Early Plate Tectonics Evidence:** A rock in South Africa provides evidence suggesting that plate tectonics began early in Earth\'s history, with 3-billion-year-old landslide scars possibly caused by an earthquake triggered by colliding crustal slabs.
# *   **Martian Microbes (Potential):** NASA\'s Perseverance rover uncovered a rock on Mars with white spots and black rings containing iron phosphate, which on Earth are linked to ancient microbial life, hinting at possible past life on Mars.
# *   **Mapping Greenland\'s Sub-ice Geology:** Combining geophysical data from seismometers, remote sensing, and airborne campaigns, a new map of Greenland\'s geology beneath its ice sheet has been developed, revealing insights into solid-Earth boundary conditions influencing ice flow.
# *   **Catastrophic Landslide Forecasting:** Research is advancing in forecasting catastrophic landslides by differentiating between slow, accelerating deformation preceding large events and persistent motion of slow-moving landslides, utilizing satellite remote sensing data for early warning systems.
# *   **Permafrost Degradation:** A case study in Arctic Alaska confirmed that oil well pads accelerate permafrost degradation, highlighting long-term environmental consequences.
#
# Total number of papers: 13
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: research_paper_finder_agent
# [logging_plugin]    Invocation ID: e-38c8caf4-818e-47da-925b-e39ed7f29f20
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-38c8caf4-818e-47da-925b-e39ed7f29f20
# [logging_plugin]    Final Agent: research_paper_finder_agent
